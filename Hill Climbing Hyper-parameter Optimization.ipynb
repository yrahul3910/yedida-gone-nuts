# %%
from raise_utils.learners import FeedforwardDL, Learner
from raise_utils.transform import Transform
from typing import Callable
from raise_utils.data import DataLoader, Data
from raise_utils.metrics import ClassificationMetrics
import random
import copy
import time

# %%
class SteppedSearch:
    def __init__(self, params: dict, metrics: list, data: Data, n_iters: int, model_fn: Callable):
        """
        Initializes the hyper-parameter optimizer.
        
        :param params: dict - dict of hyper-parameters to tune. The schema is as follows:
        {
            "param_name": {
                "start": Any,
                "range": Union[list, tuple],
                "step_size": Union[int, float],
                "is_learner_param": bool                
            }
        }
        Please put the params with a list type of range at the end.
        """
        self.params = params
        self.metrics = metrics
        self.data = data
        self.n_iters = n_iters
        self.model_fn = model_fn
        self.cur_hp_dict = {k: v["start"] for k, v in self.params.items()}
        self.cache = {}
    
    def _get_model_performance(self, model: Learner, pre: str):
        cache_str = '|'.join([str(self.cur_hp_dict[x]) for x in self.cur_hp_dict.keys()])
        if cache_str in self.cache:
            return self.cache[cache_str]
        
        transform = Transform(pre)
        dt = copy.deepcopy(self.data)
        transform.apply(dt)
        model.set_data(*dt)
        model.fit()
        preds = model.predict(self.data.x_test)
        metr = ClassificationMetrics(self.data.y_test, preds)
        metr.add_metrics(self.metrics)
        perfs = metr.get_metrics()
        
        self.cache[cache_str] = perfs
        return perfs
        
    def _in_range(self, param, val):
        if isinstance(self.params[param]["range"], list):
            return True
        
        return self.params[param]["range"][0] <= val <= self.params[param]["range"][1]
    
    def _get_next_trend_step(self, cur_hp_dict: dict, cur_trend: dict):
        print(cur_hp_dict, cur_trend)
        if cur_trend:
            # Not our first run
            # What are we trying now?
            cur_param = list(cur_trend.keys())[0]
            
            if isinstance(self.params[cur_param]["range"], list):
                pass
            else:
                if self._in_range(cur_param, cur_trend[cur_param] + cur_trend["trend"] * self.params[cur_param]["step_size"]):
                    cur_trend[cur_param] += cur_trend["trend"] * self.params[cur_param]["step_size"]
                    return cur_trend
                
                # Try the next one
                idx = list(self.params.keys()).index(cur_param)
                if idx == len(self.params):
                    return False
                else:
                    cur_param = list(self.params.keys())[idx + 1]
                    cur_trend = {cur_param: self.params[cur_param]["start"], "trend": +1}
                    return cur_trend
        else:
            # First run            
            cur_param = list(self.params.keys())[0]
            cur_trend = {cur_param: self.params[cur_param]["start"] + self.params[cur_param]["step_size"], "trend": +1}
            return cur_trend
    
    def optimize(self):
        cur_trend = {}
        cur_best = -1.
        cur_best_perfs = []
        cur_best_config = copy.deepcopy(self.cur_hp_dict)
        i = 1
        
        while i <= self.n_iters:
            print('iter', i)
            i += 1
            # Get the model
            model = self.model_fn(self.cur_hp_dict)
            
            # Test it
            perfs = self._get_model_performance(model, self.cur_hp_dict["preprocessor"])
            
            # Did we improve?
            if perfs[0] > cur_best:
                # Save this config
                cur_best = perfs[0]
                cur_best_perfs = perfs
                cur_best_config = copy.deepcopy(self.cur_hp_dict)
                
                # Get our next update (else fail)
                cur_trend = self._get_next_trend_step(self.cur_hp_dict, cur_trend)
                if cur_trend == False:
                    print('Complete')
                    return cur_best_config, cur_best_perfs
                cur_param = list(cur_trend.keys())[0]
                self.cur_hp_dict[cur_param] = cur_trend[cur_param]
                # TODO: Set cur_hp_dict....probably needs rewriting since loop needed
            else:
                # Was this a choice or a range?
                cur_param = list(cur_trend.keys())[0]
                if isinstance(self.params[cur_param]["range"], list):
                    # As long as there's something to try
                    while self.params[cur_param]["range"].index(cur_trend[cur_param]) < len(self.params[cur_param]["range"]) - 1:
                        idx = self.params[cur_param]["range"].index(cur_trend[cur_param])
                        cur_param_val = self.params[cur_param]["range"][idx + 1]
                        tmp = copy.deepcopy(self.cur_hp_dict)
                        tmp[cur_param] = cur_param_val
                        
                        # Is it better?
                        perfs = self._get_model_performance(self.model_fn(tmp), tmp["preprocessor"])
                        if perfs[0] > cur_best:
                            # Save this config
                            cur_best = perfs[0]
                            cur_best_perfs = perfs
                            cur_best_config = copy.deepcopy(self.cur_hp_dict)
                            self.cur_hp_dict[cur_param] = cur_param_val
                            cur_trend[cur_param] = cur_param_val
                        else:
                            # Try the next one
                            cur_trend[cur_param] = cur_param_val
                    
                    # cur_best_config already reflects the best config for this
                    # param, so there's nothing to do here except move to the next param.
                    idx = list(self.params.keys()).index(cur_param) + 1
                    if idx == len(list(self.params.keys())):
                        # No more params to look at, we're done.
                        return cur_best_config, cur_best_perfs
                    else:
                        # Set the trend now
                        param = list(self.params.keys())[idx]
                        cur_trend = {param: self.params[param]["start"], "trend": self.params[param]["step_size"]}
                        continue
                else:
                    # Go the current way...
                    cur_trend = self._get_next_trend_step(self.cur_hp_dict, cur_trend)
                    if cur_trend == False:
                        print("Complete.")
                        return cur_best_config, cur_best_perfs
                    
                    tmp = copy.deepcopy(self.cur_hp_dict)
                    perfs = self._get_model_performance(self.model_fn(tmp), self.cur_hp_dict["preprocessor"])
                    
                    # Did it work?
                    perfs = self._get_model_performance(self.model_fn(tmp), self.cur_hp_dict["preprocessor"])
                    if perfs[0] > cur_best:
                        # Save this config
                        cur_best = perfs[0]
                        cur_best_perfs = perfs
                        cur_best_config = copy.deepcopy(self.cur_hp_dict)
                        cur_param = list(cur_trend.keys())[0]
                        self.cur_hp_dict[cur_param] = cur_trend[cur_param]
                    else:
                        # What about the other way?
                        cur_trend["trend"] = -cur_trend["trend"]
                        tmp = copy.deepcopy(self.cur_hp_dict)
                        perfs = self._get_model_performance(self.model_fn(tmp), self.cur_hp_dict["preprocessor"])

                        # Did that work?
                        if perfs[0] > cur_best:
                            # Save this config
                            cur_best = perfs[0]
                            cur_best_perfs = perfs
                            cur_best_config = copy.deepcopy(self.cur_hp_dict)
                            self.cur_hp_dict[cur_param] = cur_trend[cur_param]
                        else:
                            # This parameter is pointless. Reset and move on. We abuse
                            # the range validation in _get_next_trend_step to do this
                            # for us.
                            cur_trend[cur_param] = self.params[cur_param]["range"][1]
                            cur_trend = self._get_next_trend_step(self.cur_hp_dict, cur_trend)
                            if cur_trend == False:
                                print("Complete.")
                                return cur_best_config, cur_best_perfs

# %%
file_dic = {"ivy":     ["ivy-1.1.csv", "ivy-1.4.csv", "ivy-2.0.csv"],\
        "lucene":  ["lucene-2.0.csv", "lucene-2.2.csv", "lucene-2.4.csv"],\
        "poi":     ["poi-1.5.csv", "poi-2.0.csv", "poi-2.5.csv", "poi-3.0.csv"],\
        "synapse": ["synapse-1.0.csv", "synapse-1.1.csv", "synapse-1.2.csv"],\
        "velocity":["velocity-1.4.csv", "velocity-1.5.csv", "velocity-1.6.csv"], \
        "camel": ["camel-1.0.csv", "camel-1.2.csv", "camel-1.4.csv", "camel-1.6.csv"], \
        "jedit": ["jedit-3.2.csv", "jedit-4.0.csv", "jedit-4.1.csv", "jedit-4.2.csv", "jedit-4.3.csv"], \
        "log4j": ["log4j-1.0.csv", "log4j-1.1.csv", "log4j-1.2.csv"], \
        "xalan": ["xalan-2.4.csv", "xalan-2.5.csv", "xalan-2.6.csv", "xalan-2.7.csv"], \
        "xerces": ["xerces-1.2.csv", "xerces-1.3.csv", "xerces-1.4.csv"]
        }

# %%
metrics = ["d2h2", "pd", "pf"]

# %%
hyp = {
    "n_layers": {
        "start": 1,
        "range": (1, 5),
        "step_size": 1,
        "is_learner_param": True
    },
    "n_units": {
        "start": 3,
        "range": (3, 20),
        "step_size": 2,
        "is_learner_param": True
    },
    "preprocessor": {
        "start": "normalize",
        "range": ["normalize", "standardize", "minmax", "maxabs"],
        "step_size": 1,
        "is_learner_param": False
    }
}

# %%
def model_fn(config):
    """
    Returns a deep learner given the current config.
    """
    learner = FeedforwardDL(weighted=True, wfo=True, n_layers=config["n_layers"], 
                            n_units=config["n_units"], n_epochs=30)
    return learner

# %%
data = DataLoader.from_files(base_path='../Dodge/data/defect/', files=file_dic["ivy"])

# %%
opt = SteppedSearch(params=hyp, metrics=metrics, data=data, model_fn=model_fn, n_iters=30)

# %%
opt.optimize()
# Out:
# iter 1
# got model
# Epoch 1/30
# 75/75 [==============================] - 0s 770us/step - loss: 1.9016
# Epoch 2/30
# 75/75 [==============================] - 0s 649us/step - loss: 1.8776
# Epoch 3/30
# 75/75 [==============================] - 0s 620us/step - loss: 1.8683
# Epoch 4/30
# 75/75 [==============================] - 0s 628us/step - loss: 1.8611
# Epoch 5/30
# 75/75 [==============================] - 0s 647us/step - loss: 1.8550
# Epoch 6/30
# 75/75 [==============================] - 0s 1ms/step - loss: 1.8478
# Epoch 7/30
# 75/75 [==============================] - 0s 959us/step - loss: 1.8409
# Epoch 8/30
# 75/75 [==============================] - 0s 858us/step - loss: 1.8340
# Epoch 9/30
# 75/75 [==============================] - 0s 594us/step - loss: 1.8266
# Epoch 10/30
# 75/75 [==============================] - 0s 525us/step - loss: 1.8192
# Epoch 11/30
# 75/75 [==============================] - 0s 592us/step - loss: 1.8125
# Epoch 12/30
# 75/75 [==============================] - 0s 530us/step - loss: 1.8044
# Epoch 13/30
# 75/75 [==============================] - 0s 545us/step - loss: 1.7960
# Epoch 14/30
# 75/75 [==============================] - 0s 536us/step - loss: 1.7877
# Epoch 15/30
# 75/75 [==============================] - 0s 561us/step - loss: 1.7794
# Epoch 16/30
# 75/75 [==============================] - 0s 540us/step - loss: 1.7710
# Epoch 17/30
# 75/75 [==============================] - 0s 544us/step - loss: 1.7631
# Epoch 18/30
# 75/75 [==============================] - 0s 535us/step - loss: 1.7558
# Epoch 19/30
# 75/75 [==============================] - 0s 542us/step - loss: 1.7488
# Epoch 20/30
# 75/75 [==============================] - 0s 527us/step - loss: 1.7427
# Epoch 21/30
# 75/75 [==============================] - 0s 567us/step - loss: 1.7363
# Epoch 22/30
# 75/75 [==============================] - 0s 556us/step - loss: 1.7310
# Epoch 23/30
# 75/75 [==============================] - 0s 531us/step - loss: 1.7255
# Epoch 24/30
# 75/75 [==============================] - 0s 544us/step - loss: 1.7204
# Epoch 25/30
# 75/75 [==============================] - 0s 514us/step - loss: 1.7157
# Epoch 26/30
# 75/75 [==============================] - 0s 537us/step - loss: 1.7106
# Epoch 27/30
# 75/75 [==============================] - 0s 575us/step - loss: 1.7064
# Epoch 28/30
# 75/75 [==============================] - 0s 553us/step - loss: 1.7030
# Epoch 29/30
# 75/75 [==============================] - 0s 509us/step - loss: 1.6986
# Epoch 30/30
# 75/75 [==============================] - 0s 634us/step - loss: 1.6950
# got perfs
# {'n_layers': 1, 'n_units': 3, 'preprocessor': 'normalize'} {}
# iter 2
# got model
# Epoch 1/30
# 75/75 [==============================] - 0s 663us/step - loss: 1.8915
# Epoch 2/30
# 75/75 [==============================] - 0s 585us/step - loss: 1.8905
# Epoch 3/30
# 75/75 [==============================] - 0s 582us/step - loss: 1.8891
# Epoch 4/30
# 75/75 [==============================] - 0s 589us/step - loss: 1.8866
# Epoch 5/30
# 75/75 [==============================] - 0s 601us/step - loss: 1.8830
# Epoch 6/30
# 75/75 [==============================] - 0s 637us/step - loss: 1.8770
# Epoch 7/30
# 75/75 [==============================] - 0s 638us/step - loss: 1.8692
# Epoch 8/30
# 75/75 [==============================] - 0s 606us/step - loss: 1.8593
# Epoch 9/30
# 75/75 [==============================] - 0s 577us/step - loss: 1.8479
# Epoch 10/30
# 75/75 [==============================] - 0s 585us/step - loss: 1.8337
# Epoch 11/30
# 75/75 [==============================] - 0s 561us/step - loss: 1.8178
# Epoch 12/30
# 75/75 [==============================] - 0s 559us/step - loss: 1.8019
# Epoch 13/30
# 75/75 [==============================] - 0s 579us/step - loss: 1.7868
# Epoch 14/30
# 75/75 [==============================] - 0s 592us/step - loss: 1.7708
# Epoch 15/30
# 75/75 [==============================] - 0s 551us/step - loss: 1.7558
# Epoch 16/30
# 75/75 [==============================] - 0s 611us/step - loss: 1.7413
# Epoch 17/30
# 75/75 [==============================] - 0s 659us/step - loss: 1.7276
# Epoch 18/30
# 75/75 [==============================] - 0s 702us/step - loss: 1.7163
# Epoch 19/30
# 75/75 [==============================] - 0s 823us/step - loss: 1.7037
# Epoch 20/30
# 75/75 [==============================] - 0s 942us/step - loss: 1.6916
# Epoch 21/30
# 75/75 [==============================] - 0s 943us/step - loss: 1.6801
# Epoch 22/30
# 75/75 [==============================] - 0s 917us/step - loss: 1.6691
# Epoch 23/30
# 75/75 [==============================] - 0s 891us/step - loss: 1.6591
# Epoch 24/30
# 75/75 [==============================] - 0s 808us/step - loss: 1.6480
# Epoch 25/30
# 75/75 [==============================] - 0s 588us/step - loss: 1.6375
# Epoch 26/30
# 75/75 [==============================] - 0s 595us/step - loss: 1.6285
# Epoch 27/30
# 75/75 [==============================] - 0s 592us/step - loss: 1.6163
# Epoch 28/30
# 75/75 [==============================] - 0s 608us/step - loss: 1.6056
# Epoch 29/30
# 75/75 [==============================] - 0s 1ms/step - loss: 1.5957
# Epoch 30/30
# 75/75 [==============================] - 0s 1ms/step - loss: 1.5856
# got perfs
# in else
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 2, 'trend': 1}
# got tmp
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': -1}
# iter 3
# got model
# got perfs
# in else
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 4, 'trend': -1}
# got tmp
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': 1}
# iter 4
# got model
# got perfs
# in else
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 3, 'trend': 1}
# got tmp
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': -1}
# iter 5
# got model
# got perfs
# in else
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 18, 'trend': -1}
# got tmp
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': 1}
# iter 6
# got model
# got perfs
# in if preprocessor
# ({'n_layers': 1, 'n_units': 3, 'preprocessor': 'normalize'},
#  [0.36874602501803966, 0.9, 0.46794871794871795])

# %%
for dataset in file_dic.keys():
    print(dataset)
    print('=' * len(dataset))
    data = DataLoader.from_files(base_path='../Dodge/data/defect/', files=file_dic[dataset])
    opt = SteppedSearch(params=hyp, metrics=metrics, data=data, model_fn=model_fn, n_iters=30)
    start = time.time()
    config, perfs = opt.optimize()
    end = time.time()
    print('Time taken:', round(end - start, 2), 'seconds.')
    print(perfs)
# Out:
# ivy
# ===
# iter 1
# Epoch 1/30
# 75/75 [==============================] - 0s 607us/step - loss: 1.8909
# Epoch 2/30
# 75/75 [==============================] - 0s 538us/step - loss: 1.8904
# Epoch 3/30
# 75/75 [==============================] - 0s 525us/step - loss: 1.8871
# Epoch 4/30
# 75/75 [==============================] - 0s 578us/step - loss: 1.8775
# Epoch 5/30
# 75/75 [==============================] - 0s 515us/step - loss: 1.8674
# Epoch 6/30
# 75/75 [==============================] - 0s 576us/step - loss: 1.8565
# Epoch 7/30
# 75/75 [==============================] - 0s 521us/step - loss: 1.8452
# Epoch 8/30
# 75/75 [==============================] - 0s 626us/step - loss: 1.8340
# Epoch 9/30
# 75/75 [==============================] - 0s 611us/step - loss: 1.8237
# Epoch 10/30
# 75/75 [==============================] - 0s 571us/step - loss: 1.8137
# Epoch 11/30
# 75/75 [==============================] - 0s 544us/step - loss: 1.8058
# Epoch 12/30
# 75/75 [==============================] - 0s 621us/step - loss: 1.7984
# Epoch 13/30
# 75/75 [==============================] - 0s 748us/step - loss: 1.7912
# Epoch 14/30
# 75/75 [==============================] - 0s 709us/step - loss: 1.7845
# Epoch 15/30
# 75/75 [==============================] - 0s 526us/step - loss: 1.7782
# Epoch 16/30
# 75/75 [==============================] - 0s 580us/step - loss: 1.7731
# Epoch 17/30
# 75/75 [==============================] - 0s 549us/step - loss: 1.7683
# Epoch 18/30
# 75/75 [==============================] - 0s 788us/step - loss: 1.7636
# Epoch 19/30
# 75/75 [==============================] - 0s 539us/step - loss: 1.7579
# Epoch 20/30
# 75/75 [==============================] - 0s 548us/step - loss: 1.7525
# Epoch 21/30
# 75/75 [==============================] - 0s 690us/step - loss: 1.7456
# Epoch 22/30
# 75/75 [==============================] - 0s 940us/step - loss: 1.7395
# Epoch 23/30
# 75/75 [==============================] - 0s 756us/step - loss: 1.7326
# Epoch 24/30
# 75/75 [==============================] - 0s 754us/step - loss: 1.7261
# Epoch 25/30
# 75/75 [==============================] - 0s 689us/step - loss: 1.7200
# Epoch 26/30
# 75/75 [==============================] - 0s 590us/step - loss: 1.7142
# Epoch 27/30
# 75/75 [==============================] - 0s 613us/step - loss: 1.7079
# Epoch 28/30
# 75/75 [==============================] - 0s 552us/step - loss: 1.7019
# Epoch 29/30
# 75/75 [==============================] - 0s 601us/step - loss: 1.6966
# Epoch 30/30
# 75/75 [==============================] - 0s 540us/step - loss: 1.6907
# {'n_layers': 1, 'n_units': 3, 'preprocessor': 'normalize'} {}
# iter 2
# Epoch 1/30
# 75/75 [==============================] - 0s 774us/step - loss: 1.8977
# Epoch 2/30
# 75/75 [==============================] - 0s 666us/step - loss: 1.8899
# Epoch 3/30
# 75/75 [==============================] - 0s 704us/step - loss: 1.8864
# Epoch 4/30
# 75/75 [==============================] - 0s 735us/step - loss: 1.8816
# Epoch 5/30
# 75/75 [==============================] - 0s 981us/step - loss: 1.8730
# Epoch 6/30
# 75/75 [==============================] - 0s 651us/step - loss: 1.8594
# Epoch 7/30
# 75/75 [==============================] - 0s 568us/step - loss: 1.8423
# Epoch 8/30
# 75/75 [==============================] - 0s 660us/step - loss: 1.8261
# Epoch 9/30
# 75/75 [==============================] - 0s 634us/step - loss: 1.8139
# Epoch 10/30
# 75/75 [==============================] - 0s 642us/step - loss: 1.8004
# Epoch 11/30
# 75/75 [==============================] - 0s 642us/step - loss: 1.7907
# Epoch 12/30
# 75/75 [==============================] - 0s 784us/step - loss: 1.7825
# Epoch 13/30
# 75/75 [==============================] - 0s 657us/step - loss: 1.7764
# Epoch 14/30
# 75/75 [==============================] - 0s 630us/step - loss: 1.7700
# Epoch 15/30
# 75/75 [==============================] - 0s 615us/step - loss: 1.7642
# Epoch 16/30
# 75/75 [==============================] - 0s 607us/step - loss: 1.7595
# Epoch 17/30
# 75/75 [==============================] - 0s 594us/step - loss: 1.7524
# Epoch 18/30
# 75/75 [==============================] - 0s 542us/step - loss: 1.7460
# Epoch 19/30
# 75/75 [==============================] - 0s 613us/step - loss: 1.7407
# Epoch 20/30
# 75/75 [==============================] - 0s 578us/step - loss: 1.7320
# Epoch 21/30
# 75/75 [==============================] - 0s 592us/step - loss: 1.7226
# Epoch 22/30
# 75/75 [==============================] - 0s 606us/step - loss: 1.7130
# Epoch 23/30
# 75/75 [==============================] - 0s 533us/step - loss: 1.7026
# Epoch 24/30
# 75/75 [==============================] - 0s 518us/step - loss: 1.6916
# Epoch 25/30
# 75/75 [==============================] - 0s 542us/step - loss: 1.6812
# Epoch 26/30
# 75/75 [==============================] - 0s 512us/step - loss: 1.6686
# Epoch 27/30
# 75/75 [==============================] - 0s 538us/step - loss: 1.6552
# Epoch 28/30
# 75/75 [==============================] - 0s 514us/step - loss: 1.6414
# Epoch 29/30
# 75/75 [==============================] - 0s 556us/step - loss: 1.6285
# Epoch 30/30
# 75/75 [==============================] - 0s 523us/step - loss: 1.6127
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 2, 'trend': 1}
# iter 3
# Epoch 1/30
# 75/75 [==============================] - 0s 697us/step - loss: 1.8892
# Epoch 2/30
# 75/75 [==============================] - 0s 597us/step - loss: 1.8839
# Epoch 3/30
# 75/75 [==============================] - 0s 668us/step - loss: 1.8736
# Epoch 4/30
# 75/75 [==============================] - 0s 923us/step - loss: 1.8602
# Epoch 5/30
# 75/75 [==============================] - 0s 1ms/step - loss: 1.8370
# Epoch 6/30
# 75/75 [==============================] - 0s 1ms/step - loss: 1.8027
# Epoch 7/30
# 75/75 [==============================] - 0s 1ms/step - loss: 1.7691
# Epoch 8/30
# 75/75 [==============================] - 0s 1ms/step - loss: 1.7384
# Epoch 9/30
# 75/75 [==============================] - 0s 1ms/step - loss: 1.7095
# Epoch 10/30
# 75/75 [==============================] - 0s 1ms/step - loss: 1.6728
# Epoch 11/30
# 75/75 [==============================] - 0s 1ms/step - loss: 1.6414
# Epoch 12/30
# 75/75 [==============================] - 0s 970us/step - loss: 1.6118
# Epoch 13/30
# 75/75 [==============================] - 0s 838us/step - loss: 1.5888
# Epoch 14/30
# 75/75 [==============================] - 0s 773us/step - loss: 1.5665
# Epoch 15/30
# 75/75 [==============================] - 0s 948us/step - loss: 1.5424
# Epoch 16/30
# 75/75 [==============================] - 0s 954us/step - loss: 1.5221
# Epoch 17/30
# 75/75 [==============================] - 0s 903us/step - loss: 1.5026
# Epoch 18/30
# 75/75 [==============================] - 0s 898us/step - loss: 1.4872
# Epoch 19/30
# 75/75 [==============================] - 0s 1ms/step - loss: 1.4747
# Epoch 20/30
# 75/75 [==============================] - 0s 957us/step - loss: 1.4589
# Epoch 21/30
# 75/75 [==============================] - 0s 857us/step - loss: 1.4499
# Epoch 22/30
# 75/75 [==============================] - 0s 777us/step - loss: 1.4384
# Epoch 23/30
# 75/75 [==============================] - 0s 985us/step - loss: 1.4310
# Epoch 24/30
# 75/75 [==============================] - 0s 902us/step - loss: 1.4228
# Epoch 25/30
# 75/75 [==============================] - 0s 806us/step - loss: 1.4146
# Epoch 26/30
# 75/75 [==============================] - 0s 805us/step - loss: 1.4064
# Epoch 27/30
# 75/75 [==============================] - 0s 856us/step - loss: 1.4000
# Epoch 28/30
# 75/75 [==============================] - 0s 918us/step - loss: 1.4000
# Epoch 29/30
# 75/75 [==============================] - 0s 946us/step - loss: 1.3899
# Epoch 30/30
# 75/75 [==============================] - 0s 842us/step - loss: 1.3850
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 3, 'trend': 1}
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': -1}
# iter 4
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 4, 'trend': -1}
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': 1}
# iter 5
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 3, 'trend': 1}
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': -1}
# iter 6
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 18, 'trend': -1}
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': 1}
# iter 7
# Time taken: 6.62 seconds.
# [0.3897129829757613, 0.65, 0.1987179487179487]
# lucene
# ======
# iter 1
# Epoch 1/30
# 45/45 [==============================] - 0s 732us/step - loss: 0.9932
# Epoch 2/30
# 45/45 [==============================] - 0s 675us/step - loss: 0.9909
# Epoch 3/30
# 45/45 [==============================] - 0s 795us/step - loss: 0.9889
# Epoch 4/30
# 45/45 [==============================] - 0s 684us/step - loss: 0.9872
# Epoch 5/30
# 45/45 [==============================] - 0s 674us/step - loss: 0.9857
# Epoch 6/30
# 45/45 [==============================] - 0s 691us/step - loss: 0.9845
# Epoch 7/30
# 45/45 [==============================] - 0s 668us/step - loss: 0.9832
# Epoch 8/30
# 45/45 [==============================] - 0s 715us/step - loss: 0.9822
# Epoch 9/30
# 45/45 [==============================] - 0s 709us/step - loss: 0.9811
# Epoch 10/30
# 45/45 [==============================] - 0s 857us/step - loss: 0.9803
# Epoch 11/30
# 45/45 [==============================] - 0s 773us/step - loss: 0.9791
# Epoch 12/30
# 45/45 [==============================] - 0s 664us/step - loss: 0.9781
# Epoch 13/30
# 45/45 [==============================] - 0s 670us/step - loss: 0.9771
# Epoch 14/30
# 45/45 [==============================] - 0s 848us/step - loss: 0.9759
# Epoch 15/30
# 45/45 [==============================] - 0s 879us/step - loss: 0.9747
# Epoch 16/30
# 45/45 [==============================] - 0s 771us/step - loss: 0.9732
# Epoch 17/30
# 45/45 [==============================] - 0s 649us/step - loss: 0.9715
# Epoch 18/30
# 45/45 [==============================] - 0s 612us/step - loss: 0.9692
# Epoch 19/30
# 45/45 [==============================] - 0s 670us/step - loss: 0.9671
# Epoch 20/30
# 45/45 [==============================] - 0s 602us/step - loss: 0.9648
# Epoch 21/30
# 45/45 [==============================] - 0s 529us/step - loss: 0.9621
# Epoch 22/30
# 45/45 [==============================] - 0s 551us/step - loss: 0.9602
# Epoch 23/30
# 45/45 [==============================] - 0s 593us/step - loss: 0.9584
# Epoch 24/30
# 45/45 [==============================] - 0s 569us/step - loss: 0.9559
# Epoch 25/30
# 45/45 [==============================] - 0s 555us/step - loss: 0.9533
# Epoch 26/30
# 45/45 [==============================] - 0s 594us/step - loss: 0.9500
# Epoch 27/30
# 45/45 [==============================] - 0s 555us/step - loss: 0.9475
# Epoch 28/30
# 45/45 [==============================] - 0s 556us/step - loss: 0.9455
# Epoch 29/30
# 45/45 [==============================] - 0s 590us/step - loss: 0.9434
# Epoch 30/30
# 45/45 [==============================] - 0s 543us/step - loss: 0.9410
# {'n_layers': 1, 'n_units': 3, 'preprocessor': 'normalize'} {}
# iter 2
# Epoch 1/30
# 45/45 [==============================] - 0s 658us/step - loss: 0.9932
# Epoch 2/30
# 45/45 [==============================] - 0s 630us/step - loss: 0.9854
# Epoch 3/30
# 45/45 [==============================] - 0s 747us/step - loss: 0.9799
# Epoch 4/30
# 45/45 [==============================] - 0s 724us/step - loss: 0.9766
# Epoch 5/30
# 45/45 [==============================] - 0s 734us/step - loss: 0.9738
# Epoch 6/30
# 45/45 [==============================] - 0s 717us/step - loss: 0.9705
# Epoch 7/30
# 45/45 [==============================] - 0s 693us/step - loss: 0.9679
# Epoch 8/30
# 45/45 [==============================] - 0s 706us/step - loss: 0.9639
# Epoch 9/30
# 45/45 [==============================] - 0s 793us/step - loss: 0.9602
# Epoch 10/30
# 45/45 [==============================] - 0s 740us/step - loss: 0.9566
# Epoch 11/30
# 45/45 [==============================] - 0s 665us/step - loss: 0.9529
# Epoch 12/30
# 45/45 [==============================] - 0s 692us/step - loss: 0.9494
# Epoch 13/30
# 45/45 [==============================] - 0s 591us/step - loss: 0.9455
# Epoch 14/30
# 45/45 [==============================] - 0s 689us/step - loss: 0.9424
# Epoch 15/30
# 45/45 [==============================] - 0s 665us/step - loss: 0.9398
# Epoch 16/30
# 45/45 [==============================] - 0s 622us/step - loss: 0.9375
# Epoch 17/30
# 45/45 [==============================] - 0s 583us/step - loss: 0.9343
# Epoch 18/30
# 45/45 [==============================] - 0s 573us/step - loss: 0.9324
# Epoch 19/30
# 45/45 [==============================] - 0s 646us/step - loss: 0.9300
# Epoch 20/30
# 45/45 [==============================] - 0s 622us/step - loss: 0.9279
# Epoch 21/30
# 45/45 [==============================] - 0s 718us/step - loss: 0.9276
# Epoch 22/30
# 45/45 [==============================] - 0s 633us/step - loss: 0.9247
# Epoch 23/30
# 45/45 [==============================] - 0s 570us/step - loss: 0.9236
# Epoch 24/30
# 45/45 [==============================] - 0s 565us/step - loss: 0.9210
# Epoch 25/30
# 45/45 [==============================] - 0s 604us/step - loss: 0.9204
# Epoch 26/30
# 45/45 [==============================] - 0s 569us/step - loss: 0.9181
# Epoch 27/30
# 45/45 [==============================] - 0s 567us/step - loss: 0.9173
# Epoch 28/30
# 45/45 [==============================] - 0s 608us/step - loss: 0.9169
# Epoch 29/30
# 45/45 [==============================] - 0s 578us/step - loss: 0.9164
# Epoch 30/30
# 45/45 [==============================] - 0s 557us/step - loss: 0.9140
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 2, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': -1}
# iter 3
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 4, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': 1}
# iter 4
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 3, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': -1}
# iter 5
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 18, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': 1}
# iter 6
# Time taken: 2.77 seconds.
# [0.06173719900750041, 0.7487684729064039, 0.6204379562043796]
# poi
# ===
# iter 1
# Epoch 1/30
# 187/187 [==============================] - 0s 703us/step - loss: 1.1010
# Epoch 2/30
# 187/187 [==============================] - 0s 2ms/step - loss: 1.0822
# Epoch 3/30
# 187/187 [==============================] - 0s 566us/step - loss: 1.0626
# Epoch 4/30
# 187/187 [==============================] - 0s 523us/step - loss: 1.0454
# Epoch 5/30
# 187/187 [==============================] - 0s 470us/step - loss: 1.0323
# Epoch 6/30
# 187/187 [==============================] - 0s 465us/step - loss: 1.0229
# Epoch 7/30
# 187/187 [==============================] - 0s 460us/step - loss: 1.0165
# Epoch 8/30
# 187/187 [==============================] - 0s 454us/step - loss: 1.0121
# Epoch 9/30
# 187/187 [==============================] - 0s 459us/step - loss: 1.0093
# Epoch 10/30
# 187/187 [==============================] - 0s 466us/step - loss: 1.0071
# Epoch 11/30
# 187/187 [==============================] - 0s 508us/step - loss: 1.0051
# Epoch 12/30
# 187/187 [==============================] - 0s 515us/step - loss: 1.0042
# Epoch 13/30
# 187/187 [==============================] - 0s 461us/step - loss: 1.0029
# Epoch 14/30
# 187/187 [==============================] - 0s 473us/step - loss: 1.0020
# Epoch 15/30
# 187/187 [==============================] - 0s 461us/step - loss: 1.0009
# Epoch 16/30
# 187/187 [==============================] - 0s 518us/step - loss: 1.0007
# Epoch 17/30
# 187/187 [==============================] - 0s 462us/step - loss: 0.9992
# Epoch 18/30
# 187/187 [==============================] - 0s 459us/step - loss: 0.9988
# Epoch 19/30
# 187/187 [==============================] - 0s 459us/step - loss: 0.9979
# Epoch 20/30
# 187/187 [==============================] - 0s 474us/step - loss: 0.9973
# Epoch 21/30
# 187/187 [==============================] - 0s 492us/step - loss: 0.9967
# Epoch 22/30
# 187/187 [==============================] - 0s 1ms/step - loss: 0.9960
# Epoch 23/30
# 187/187 [==============================] - 0s 531us/step - loss: 0.9950
# Epoch 24/30
# 187/187 [==============================] - 0s 622us/step - loss: 0.9949
# Epoch 25/30
# 187/187 [==============================] - 0s 525us/step - loss: 0.9941
# Epoch 26/30
# 187/187 [==============================] - 0s 524us/step - loss: 0.9937
# Epoch 27/30
# 187/187 [==============================] - 0s 495us/step - loss: 0.9934
# Epoch 28/30
# 187/187 [==============================] - 0s 537us/step - loss: 0.9928
# Epoch 29/30
# 187/187 [==============================] - 0s 505us/step - loss: 0.9925
# Epoch 30/30
# 187/187 [==============================] - 0s 546us/step - loss: 0.9916
# {'n_layers': 1, 'n_units': 3, 'preprocessor': 'normalize'} {}
# iter 2
# Epoch 1/30
# 187/187 [==============================] - 0s 611us/step - loss: 1.1194
# Epoch 2/30
# 187/187 [==============================] - 0s 561us/step - loss: 1.0779
# Epoch 3/30
# 187/187 [==============================] - 0s 609us/step - loss: 1.0518
# Epoch 4/30
# 187/187 [==============================] - 0s 600us/step - loss: 1.0312
# Epoch 5/30
# 187/187 [==============================] - 0s 591us/step - loss: 1.0160
# Epoch 6/30
# 187/187 [==============================] - 0s 618us/step - loss: 1.0048
# Epoch 7/30
# 187/187 [==============================] - 0s 605us/step - loss: 0.9960
# Epoch 8/30
# 187/187 [==============================] - 0s 678us/step - loss: 0.9880
# Epoch 9/30
# 187/187 [==============================] - 0s 642us/step - loss: 0.9803
# Epoch 10/30
# 187/187 [==============================] - 0s 733us/step - loss: 0.9727
# Epoch 11/30
# 187/187 [==============================] - 0s 706us/step - loss: 0.9665
# Epoch 12/30
# 187/187 [==============================] - 0s 530us/step - loss: 0.9597
# Epoch 13/30
# 187/187 [==============================] - 0s 536us/step - loss: 0.9546
# Epoch 14/30
# 187/187 [==============================] - 0s 545us/step - loss: 0.9482
# Epoch 15/30
# 187/187 [==============================] - 0s 499us/step - loss: 0.9414
# Epoch 16/30
# 187/187 [==============================] - 0s 507us/step - loss: 0.9360
# Epoch 17/30
# 187/187 [==============================] - 0s 502us/step - loss: 0.9292
# Epoch 18/30
# 187/187 [==============================] - 0s 516us/step - loss: 0.9245
# Epoch 19/30
# 187/187 [==============================] - 0s 505us/step - loss: 0.9196
# Epoch 20/30
# 187/187 [==============================] - 0s 517us/step - loss: 0.9135
# Epoch 21/30
# 187/187 [==============================] - 0s 604us/step - loss: 0.9090
# Epoch 22/30
# 187/187 [==============================] - 0s 616us/step - loss: 0.9055
# Epoch 23/30
# 187/187 [==============================] - 0s 734us/step - loss: 0.8998
# Epoch 24/30
# 187/187 [==============================] - 0s 632us/step - loss: 0.8987
# Epoch 25/30
# 187/187 [==============================] - 0s 626us/step - loss: 0.8940
# Epoch 26/30
# 187/187 [==============================] - 0s 627us/step - loss: 0.8905
# Epoch 27/30
# 187/187 [==============================] - 0s 615us/step - loss: 0.8882
# Epoch 28/30
# 187/187 [==============================] - 0s 563us/step - loss: 0.8839
# Epoch 29/30
# 187/187 [==============================] - 0s 592us/step - loss: 0.8823
# Epoch 30/30
# 187/187 [==============================] - 0s 568us/step - loss: 0.8780
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 2, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': -1}
# iter 3
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 4, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': 1}
# iter 4
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 3, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': -1}
# iter 5
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 18, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': 1}
# iter 6
# Time taken: 7.64 seconds.
# [0.27010871582221585, 0.8113879003558719, 0.4161490683229814]
# synapse
# =======
# iter 1
# Epoch 1/30
# 72/72 [==============================] - 0s 548us/step - loss: 2.0927
# Epoch 2/30
# 72/72 [==============================] - 0s 517us/step - loss: 2.0649
# Epoch 3/30
# 72/72 [==============================] - 0s 503us/step - loss: 2.0544
# Epoch 4/30
# 72/72 [==============================] - 0s 505us/step - loss: 2.0470
# Epoch 5/30
# 72/72 [==============================] - 0s 509us/step - loss: 2.0395
# Epoch 6/30
# 72/72 [==============================] - 0s 497us/step - loss: 2.0309
# Epoch 7/30
# 72/72 [==============================] - 0s 501us/step - loss: 2.0225
# Epoch 8/30
# 72/72 [==============================] - 0s 497us/step - loss: 2.0126
# Epoch 9/30
# 72/72 [==============================] - 0s 522us/step - loss: 2.0024
# Epoch 10/30
# 72/72 [==============================] - 0s 501us/step - loss: 1.9920
# Epoch 11/30
# 72/72 [==============================] - 0s 518us/step - loss: 1.9804
# Epoch 12/30
# 72/72 [==============================] - 0s 511us/step - loss: 1.9683
# Epoch 13/30
# 72/72 [==============================] - 0s 493us/step - loss: 1.9572
# Epoch 14/30
# 72/72 [==============================] - 0s 504us/step - loss: 1.9441
# Epoch 15/30
# 72/72 [==============================] - 0s 498us/step - loss: 1.9319
# Epoch 16/30
# 72/72 [==============================] - 0s 546us/step - loss: 1.9163
# Epoch 17/30
# 72/72 [==============================] - 0s 582us/step - loss: 1.8994
# Epoch 18/30
# 72/72 [==============================] - 0s 501us/step - loss: 1.8844
# Epoch 19/30
# 72/72 [==============================] - 0s 518us/step - loss: 1.8693
# Epoch 20/30
# 72/72 [==============================] - 0s 497us/step - loss: 1.8513
# Epoch 21/30
# 72/72 [==============================] - 0s 522us/step - loss: 1.8326
# Epoch 22/30
# 72/72 [==============================] - 0s 495us/step - loss: 1.8156
# Epoch 23/30
# 72/72 [==============================] - 0s 498us/step - loss: 1.7983
# Epoch 24/30
# 72/72 [==============================] - 0s 494us/step - loss: 1.7811
# Epoch 25/30
# 72/72 [==============================] - 0s 509us/step - loss: 1.7651
# Epoch 26/30
# 72/72 [==============================] - 0s 499us/step - loss: 1.7498
# Epoch 27/30
# 72/72 [==============================] - 0s 498us/step - loss: 1.7340
# Epoch 28/30
# 72/72 [==============================] - 0s 496us/step - loss: 1.7189
# Epoch 29/30
# 72/72 [==============================] - 0s 495us/step - loss: 1.7049
# Epoch 30/30
# 72/72 [==============================] - 0s 496us/step - loss: 1.6908
# {'n_layers': 1, 'n_units': 3, 'preprocessor': 'normalize'} {}
# iter 2
# Epoch 1/30
# 72/72 [==============================] - 0s 1ms/step - loss: 2.1068
# Epoch 2/30
# 72/72 [==============================] - 0s 1ms/step - loss: 2.0677
# Epoch 3/30
# 72/72 [==============================] - 0s 507us/step - loss: 2.0573
# Epoch 4/30
# 72/72 [==============================] - 0s 567us/step - loss: 2.0481
# Epoch 5/30
# 72/72 [==============================] - 0s 607us/step - loss: 2.0397
# Epoch 6/30
# 72/72 [==============================] - 0s 589us/step - loss: 2.0317
# Epoch 7/30
# 72/72 [==============================] - 0s 560us/step - loss: 2.0235
# Epoch 8/30
# 72/72 [==============================] - 0s 489us/step - loss: 2.0152
# Epoch 9/30
# 72/72 [==============================] - 0s 492us/step - loss: 2.0091
# Epoch 10/30
# 72/72 [==============================] - 0s 501us/step - loss: 2.0008
# Epoch 11/30
# 72/72 [==============================] - 0s 499us/step - loss: 1.9934
# Epoch 12/30
# 72/72 [==============================] - 0s 499us/step - loss: 1.9873
# Epoch 13/30
# 72/72 [==============================] - 0s 480us/step - loss: 1.9816
# Epoch 14/30
# 72/72 [==============================] - 0s 482us/step - loss: 1.9743
# Epoch 15/30
# 72/72 [==============================] - 0s 482us/step - loss: 1.9679
# Epoch 16/30
# 72/72 [==============================] - 0s 478us/step - loss: 1.9603
# Epoch 17/30
# 72/72 [==============================] - 0s 477us/step - loss: 1.9535
# Epoch 18/30
# 72/72 [==============================] - 0s 495us/step - loss: 1.9474
# Epoch 19/30
# 72/72 [==============================] - 0s 481us/step - loss: 1.9413
# Epoch 20/30
# 72/72 [==============================] - 0s 487us/step - loss: 1.9340
# Epoch 21/30
# 72/72 [==============================] - 0s 479us/step - loss: 1.9267
# Epoch 22/30
# 72/72 [==============================] - 0s 482us/step - loss: 1.9207
# Epoch 23/30
# 72/72 [==============================] - 0s 483us/step - loss: 1.9146
# Epoch 24/30
# 72/72 [==============================] - 0s 487us/step - loss: 1.9089
# Epoch 25/30
# 72/72 [==============================] - 0s 482us/step - loss: 1.9016
# Epoch 26/30
# 72/72 [==============================] - 0s 527us/step - loss: 1.8941
# Epoch 27/30
# 72/72 [==============================] - 0s 476us/step - loss: 1.8895
# Epoch 28/30
# 72/72 [==============================] - 0s 479us/step - loss: 1.8825
# Epoch 29/30
# 72/72 [==============================] - 0s 472us/step - loss: 1.8775
# Epoch 30/30
# 72/72 [==============================] - 0s 479us/step - loss: 1.8708
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 2, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': -1}
# iter 3
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 4, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': 1}
# iter 4
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 3, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': -1}
# iter 5
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 18, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': 1}
# iter 6
# Time taken: 3.22 seconds.
# [0.1652390548288667, 0.8023255813953488, 0.5235294117647059]
# velocity
# ========
# iter 1
# Epoch 1/30
# 55/55 [==============================] - 0s 519us/step - loss: 0.8376
# Epoch 2/30
# 55/55 [==============================] - 0s 497us/step - loss: 0.8372
# Epoch 3/30
# 55/55 [==============================] - 0s 466us/step - loss: 0.8368
# Epoch 4/30
# 55/55 [==============================] - 0s 501us/step - loss: 0.8364
# Epoch 5/30
# 55/55 [==============================] - 0s 494us/step - loss: 0.8359
# Epoch 6/30
# 55/55 [==============================] - 0s 467us/step - loss: 0.8355
# Epoch 7/30
# 55/55 [==============================] - 0s 477us/step - loss: 0.8351
# Epoch 8/30
# 55/55 [==============================] - 0s 479us/step - loss: 0.8346
# Epoch 9/30
# 55/55 [==============================] - 0s 475us/step - loss: 0.8341
# Epoch 10/30
# 55/55 [==============================] - 0s 474us/step - loss: 0.8337
# Epoch 11/30
# 55/55 [==============================] - 0s 520us/step - loss: 0.8331
# Epoch 12/30
# 55/55 [==============================] - 0s 475us/step - loss: 0.8325
# Epoch 13/30
# 55/55 [==============================] - 0s 750us/step - loss: 0.8319
# Epoch 14/30
# 55/55 [==============================] - 0s 612us/step - loss: 0.8313
# Epoch 15/30
# 55/55 [==============================] - 0s 470us/step - loss: 0.8306
# Epoch 16/30
# 55/55 [==============================] - 0s 484us/step - loss: 0.8299
# Epoch 17/30
# 55/55 [==============================] - 0s 477us/step - loss: 0.8291
# Epoch 18/30
# 55/55 [==============================] - 0s 473us/step - loss: 0.8285
# Epoch 19/30
# 55/55 [==============================] - 0s 480us/step - loss: 0.8278
# Epoch 20/30
# 55/55 [==============================] - 0s 476us/step - loss: 0.8270
# Epoch 21/30
# 55/55 [==============================] - 0s 519us/step - loss: 0.8262
# Epoch 22/30
# 55/55 [==============================] - 0s 484us/step - loss: 0.8257
# Epoch 23/30
# 55/55 [==============================] - 0s 492us/step - loss: 0.8249
# Epoch 24/30
# 55/55 [==============================] - 0s 491us/step - loss: 0.8242
# Epoch 25/30
# 55/55 [==============================] - 0s 470us/step - loss: 0.8233
# Epoch 26/30
# 55/55 [==============================] - 0s 498us/step - loss: 0.8227
# Epoch 27/30
# 55/55 [==============================] - 0s 476us/step - loss: 0.8218
# Epoch 28/30
# 55/55 [==============================] - 0s 479us/step - loss: 0.8212
# Epoch 29/30
# 55/55 [==============================] - 0s 492us/step - loss: 0.8205
# Epoch 30/30
# 55/55 [==============================] - 0s 517us/step - loss: 0.8199
# {'n_layers': 1, 'n_units': 3, 'preprocessor': 'normalize'} {}
# iter 2
# Epoch 1/30
# 55/55 [==============================] - 0s 553us/step - loss: 0.8410
# Epoch 2/30
# 55/55 [==============================] - 0s 547us/step - loss: 0.8396
# Epoch 3/30
# 55/55 [==============================] - 0s 522us/step - loss: 0.8380
# Epoch 4/30
# 55/55 [==============================] - 0s 501us/step - loss: 0.8370
# Epoch 5/30
# 55/55 [==============================] - 0s 568us/step - loss: 0.8362
# Epoch 6/30
# 55/55 [==============================] - 0s 555us/step - loss: 0.8353
# Epoch 7/30
# 55/55 [==============================] - 0s 497us/step - loss: 0.8340
# Epoch 8/30
# 55/55 [==============================] - 0s 503us/step - loss: 0.8329
# Epoch 9/30
# 55/55 [==============================] - 0s 507us/step - loss: 0.8315
# Epoch 10/30
# 55/55 [==============================] - 0s 487us/step - loss: 0.8300
# Epoch 11/30
# 55/55 [==============================] - 0s 514us/step - loss: 0.8284
# Epoch 12/30
# 55/55 [==============================] - 0s 634us/step - loss: 0.8267
# Epoch 13/30
# 55/55 [==============================] - 0s 756us/step - loss: 0.8247
# Epoch 14/30
# 55/55 [==============================] - 0s 652us/step - loss: 0.8226
# Epoch 15/30
# 55/55 [==============================] - 0s 590us/step - loss: 0.8205
# Epoch 16/30
# 55/55 [==============================] - 0s 653us/step - loss: 0.8179
# Epoch 17/30
# 55/55 [==============================] - 0s 692us/step - loss: 0.8157
# Epoch 18/30
# 55/55 [==============================] - 0s 516us/step - loss: 0.8132
# Epoch 19/30
# 55/55 [==============================] - 0s 571us/step - loss: 0.8103
# Epoch 20/30
# 55/55 [==============================] - 0s 837us/step - loss: 0.8078
# Epoch 21/30
# 55/55 [==============================] - 0s 1ms/step - loss: 0.8049
# Epoch 22/30
# 55/55 [==============================] - 0s 780us/step - loss: 0.8020
# Epoch 23/30
# 55/55 [==============================] - 0s 661us/step - loss: 0.7997
# Epoch 24/30
# 55/55 [==============================] - 0s 682us/step - loss: 0.7967
# Epoch 25/30
# 55/55 [==============================] - 0s 565us/step - loss: 0.7945
# Epoch 26/30
# 55/55 [==============================] - 0s 571us/step - loss: 0.7917
# Epoch 27/30
# 55/55 [==============================] - 0s 783us/step - loss: 0.7898
# Epoch 28/30
# 55/55 [==============================] - 0s 541us/step - loss: 0.7871
# Epoch 29/30
# 55/55 [==============================] - 0s 583us/step - loss: 0.7854
# Epoch 30/30
# 55/55 [==============================] - 0s 541us/step - loss: 0.7831
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 2, 'trend': 1}
# iter 3
# Epoch 1/30
# 55/55 [==============================] - 0s 582us/step - loss: 0.8368
# Epoch 2/30
# 55/55 [==============================] - 0s 620us/step - loss: 0.8313
# Epoch 3/30
# 55/55 [==============================] - 0s 560us/step - loss: 0.8287
# Epoch 4/30
# 55/55 [==============================] - 0s 622us/step - loss: 0.8264
# Epoch 5/30
# 55/55 [==============================] - 0s 581us/step - loss: 0.8235
# Epoch 6/30
# 55/55 [==============================] - 0s 570us/step - loss: 0.8206
# Epoch 7/30
# 55/55 [==============================] - 0s 608us/step - loss: 0.8178
# Epoch 8/30
# 55/55 [==============================] - 0s 615us/step - loss: 0.8148
# Epoch 9/30
# 55/55 [==============================] - 0s 624us/step - loss: 0.8120
# Epoch 10/30
# 55/55 [==============================] - 0s 647us/step - loss: 0.8086
# Epoch 11/30
# 55/55 [==============================] - 0s 688us/step - loss: 0.8054
# Epoch 12/30
# 55/55 [==============================] - 0s 623us/step - loss: 0.8018
# Epoch 13/30
# 55/55 [==============================] - 0s 593us/step - loss: 0.7990
# Epoch 14/30
# 55/55 [==============================] - 0s 619us/step - loss: 0.7952
# Epoch 15/30
# 55/55 [==============================] - 0s 559us/step - loss: 0.7929
# Epoch 16/30
# 55/55 [==============================] - 0s 568us/step - loss: 0.7908
# Epoch 17/30
# 55/55 [==============================] - 0s 557us/step - loss: 0.7878
# Epoch 18/30
# 55/55 [==============================] - 0s 566us/step - loss: 0.7844
# Epoch 19/30
# 55/55 [==============================] - 0s 588us/step - loss: 0.7822
# Epoch 20/30
# 55/55 [==============================] - 0s 570us/step - loss: 0.7798
# Epoch 21/30
# 55/55 [==============================] - 0s 575us/step - loss: 0.7774
# Epoch 22/30
# 55/55 [==============================] - 0s 581us/step - loss: 0.7756
# Epoch 23/30
# 55/55 [==============================] - 0s 615us/step - loss: 0.7741
# Epoch 24/30
# 55/55 [==============================] - 0s 628us/step - loss: 0.7724
# Epoch 25/30
# 55/55 [==============================] - 0s 647us/step - loss: 0.7705
# Epoch 26/30
# 55/55 [==============================] - 0s 643us/step - loss: 0.7692
# Epoch 27/30
# 55/55 [==============================] - 0s 566us/step - loss: 0.7679
# Epoch 28/30
# 55/55 [==============================] - 0s 570us/step - loss: 0.7662
# Epoch 29/30
# 55/55 [==============================] - 0s 556us/step - loss: 0.7648
# Epoch 30/30
# 55/55 [==============================] - 0s 590us/step - loss: 0.7632
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 3, 'trend': 1}
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': -1}
# iter 4
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 4, 'trend': -1}
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': 1}
# iter 5
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 3, 'trend': 1}
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': -1}
# iter 6
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 18, 'trend': -1}
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': 1}
# iter 7
# Time taken: 4.24 seconds.
# [0.1626123711718005, 0.6282051282051282, 0.4768211920529801]
# camel
# =====
# iter 1
# Epoch 1/30
# 351/351 [==============================] - 0s 503us/step - loss: 2.0024
# Epoch 2/30
# 351/351 [==============================] - 0s 485us/step - loss: 1.9671
# Epoch 3/30
# 351/351 [==============================] - 0s 488us/step - loss: 1.9529
# Epoch 4/30
# 351/351 [==============================] - 0s 478us/step - loss: 1.9462
# Epoch 5/30
# 351/351 [==============================] - 0s 481us/step - loss: 1.9411
# Epoch 6/30
# 351/351 [==============================] - 0s 522us/step - loss: 1.9364
# Epoch 7/30
# 351/351 [==============================] - 0s 486us/step - loss: 1.9321
# Epoch 8/30
# 351/351 [==============================] - 0s 486us/step - loss: 1.9270
# Epoch 9/30
# 351/351 [==============================] - 0s 582us/step - loss: 1.9212
# Epoch 10/30
# 351/351 [==============================] - 0s 497us/step - loss: 1.9150
# Epoch 11/30
# 351/351 [==============================] - 0s 497us/step - loss: 1.9063
# Epoch 12/30
# 351/351 [==============================] - 0s 757us/step - loss: 1.8954
# Epoch 13/30
# 351/351 [==============================] - 0s 542us/step - loss: 1.8826
# Epoch 14/30
# 351/351 [==============================] - 0s 568us/step - loss: 1.8699
# Epoch 15/30
# 351/351 [==============================] - 0s 501us/step - loss: 1.8559
# Epoch 16/30
# 351/351 [==============================] - 0s 489us/step - loss: 1.8413
# Epoch 17/30
# 351/351 [==============================] - 0s 591us/step - loss: 1.8275
# Epoch 18/30
# 351/351 [==============================] - 0s 521us/step - loss: 1.8143
# Epoch 19/30
# 351/351 [==============================] - 0s 488us/step - loss: 1.8004
# Epoch 20/30
# 351/351 [==============================] - 0s 537us/step - loss: 1.7874
# Epoch 21/30
# 351/351 [==============================] - 0s 506us/step - loss: 1.7736
# Epoch 22/30
# 351/351 [==============================] - 0s 527us/step - loss: 1.7615
# Epoch 23/30
# 351/351 [==============================] - 0s 498us/step - loss: 1.7500
# Epoch 24/30
# 351/351 [==============================] - 0s 489us/step - loss: 1.7390
# Epoch 25/30
# 351/351 [==============================] - 0s 490us/step - loss: 1.7284
# Epoch 26/30
# 351/351 [==============================] - 0s 491us/step - loss: 1.7184
# Epoch 27/30
# 351/351 [==============================] - 0s 493us/step - loss: 1.7104
# Epoch 28/30
# 351/351 [==============================] - 0s 500us/step - loss: 1.7005
# Epoch 29/30
# 351/351 [==============================] - 0s 513us/step - loss: 1.6926
# Epoch 30/30
# 351/351 [==============================] - 0s 567us/step - loss: 1.6854
# {'n_layers': 1, 'n_units': 3, 'preprocessor': 'normalize'} {}
# iter 2
# Epoch 1/30
# 351/351 [==============================] - 0s 606us/step - loss: 2.0175
# Epoch 2/30
# 351/351 [==============================] - 0s 615us/step - loss: 1.9670
# Epoch 3/30
# 351/351 [==============================] - 0s 606us/step - loss: 1.8872
# Epoch 4/30
# 351/351 [==============================] - 0s 609us/step - loss: 1.8249
# Epoch 5/30
# 351/351 [==============================] - 0s 601us/step - loss: 1.7678
# Epoch 6/30
# 351/351 [==============================] - 0s 560us/step - loss: 1.7125
# Epoch 7/30
# 351/351 [==============================] - 0s 560us/step - loss: 1.6647
# Epoch 8/30
# 351/351 [==============================] - 0s 590us/step - loss: 1.6305
# Epoch 9/30
# 351/351 [==============================] - 0s 576us/step - loss: 1.6042
# Epoch 10/30
# 351/351 [==============================] - 0s 582us/step - loss: 1.5856
# Epoch 11/30
# 351/351 [==============================] - 0s 935us/step - loss: 1.5711
# Epoch 12/30
# 351/351 [==============================] - 0s 616us/step - loss: 1.5571
# Epoch 13/30
# 351/351 [==============================] - 0s 544us/step - loss: 1.5469
# Epoch 14/30
# 351/351 [==============================] - 0s 524us/step - loss: 1.5368
# Epoch 15/30
# 351/351 [==============================] - 0s 506us/step - loss: 1.5281
# Epoch 16/30
# 351/351 [==============================] - 0s 520us/step - loss: 1.5221
# Epoch 17/30
# 351/351 [==============================] - 0s 588us/step - loss: 1.5154
# Epoch 18/30
# 351/351 [==============================] - 0s 542us/step - loss: 1.5101
# Epoch 19/30
# 351/351 [==============================] - 0s 510us/step - loss: 1.5053
# Epoch 20/30
# 351/351 [==============================] - 0s 509us/step - loss: 1.5000
# Epoch 21/30
# 351/351 [==============================] - 0s 493us/step - loss: 1.4938
# Epoch 22/30
# 351/351 [==============================] - 0s 495us/step - loss: 1.4887
# Epoch 23/30
# 351/351 [==============================] - 0s 493us/step - loss: 1.4861
# Epoch 24/30
# 351/351 [==============================] - 0s 502us/step - loss: 1.4817
# Epoch 25/30
# 351/351 [==============================] - 0s 528us/step - loss: 1.4774
# Epoch 26/30
# 351/351 [==============================] - 0s 496us/step - loss: 1.4743
# Epoch 27/30
# 351/351 [==============================] - 0s 496us/step - loss: 1.4712
# Epoch 28/30
# 351/351 [==============================] - 0s 498us/step - loss: 1.4663
# Epoch 29/30
# 351/351 [==============================] - 0s 512us/step - loss: 1.4637
# Epoch 30/30
# 351/351 [==============================] - 0s 510us/step - loss: 1.4585
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 2, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': -1}
# iter 3
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 4, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': 1}
# iter 4
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 3, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': -1}
# iter 5
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 18, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': 1}
# iter 6
# Time taken: 12.5 seconds.
# [-0.23369867802505173, 0.9946808510638298, 0.9407979407979408]
# jedit
# =====
# iter 1
# Epoch 1/30
# 274/274 [==============================] - 0s 548us/step - loss: 1.8262
# Epoch 2/30
# 274/274 [==============================] - 0s 499us/step - loss: 1.7841
# Epoch 3/30
# 274/274 [==============================] - 0s 511us/step - loss: 1.7380
# Epoch 4/30
# 274/274 [==============================] - 0s 490us/step - loss: 1.6975
# Epoch 5/30
# 274/274 [==============================] - 0s 533us/step - loss: 1.6659
# Epoch 6/30
# 274/274 [==============================] - 0s 532us/step - loss: 1.6421
# Epoch 7/30
# 274/274 [==============================] - 0s 498us/step - loss: 1.6241
# Epoch 8/30
# 274/274 [==============================] - 0s 496us/step - loss: 1.6105
# Epoch 9/30
# 274/274 [==============================] - 0s 614us/step - loss: 1.5998
# Epoch 10/30
# 274/274 [==============================] - 0s 597us/step - loss: 1.5916
# Epoch 11/30
# 274/274 [==============================] - 0s 568us/step - loss: 1.5849
# Epoch 12/30
# 274/274 [==============================] - 0s 559us/step - loss: 1.5797
# Epoch 13/30
# 274/274 [==============================] - 0s 613us/step - loss: 1.5750
# Epoch 14/30
# 274/274 [==============================] - 0s 559us/step - loss: 1.5714
# Epoch 15/30
# 274/274 [==============================] - 0s 593us/step - loss: 1.5680
# Epoch 16/30
# 274/274 [==============================] - 0s 593us/step - loss: 1.5650
# Epoch 17/30
# 274/274 [==============================] - 0s 585us/step - loss: 1.5622
# Epoch 18/30
# 274/274 [==============================] - 0s 536us/step - loss: 1.5597
# Epoch 19/30
# 274/274 [==============================] - 0s 625us/step - loss: 1.5578
# Epoch 20/30
# 274/274 [==============================] - 0s 596us/step - loss: 1.5556
# Epoch 21/30
# 274/274 [==============================] - 0s 600us/step - loss: 1.5535
# Epoch 22/30
# 274/274 [==============================] - 0s 672us/step - loss: 1.5515
# Epoch 23/30
# 274/274 [==============================] - 0s 657us/step - loss: 1.5498
# Epoch 24/30
# 274/274 [==============================] - 0s 622us/step - loss: 1.5482
# Epoch 25/30
# 274/274 [==============================] - 0s 591us/step - loss: 1.5466
# Epoch 26/30
# 274/274 [==============================] - 0s 704us/step - loss: 1.5446
# Epoch 27/30
# 274/274 [==============================] - 0s 592us/step - loss: 1.5432
# Epoch 28/30
# 274/274 [==============================] - 0s 664us/step - loss: 1.5416
# Epoch 29/30
# 274/274 [==============================] - 0s 625us/step - loss: 1.5400
# Epoch 30/30
# 274/274 [==============================] - 0s 535us/step - loss: 1.5386
# {'n_layers': 1, 'n_units': 3, 'preprocessor': 'normalize'} {}
# iter 2
# Epoch 1/30
# 274/274 [==============================] - 0s 687us/step - loss: 1.7655
# Epoch 2/30
# 274/274 [==============================] - 0s 617us/step - loss: 1.6760
# Epoch 3/30
# 274/274 [==============================] - 0s 586us/step - loss: 1.6337
# Epoch 4/30
# 274/274 [==============================] - 0s 705us/step - loss: 1.6085
# Epoch 5/30
# 274/274 [==============================] - 0s 683us/step - loss: 1.5930
# Epoch 6/30
# 274/274 [==============================] - 0s 829us/step - loss: 1.5815
# Epoch 7/30
# 274/274 [==============================] - 0s 756us/step - loss: 1.5722
# Epoch 8/30
# 274/274 [==============================] - 0s 734us/step - loss: 1.5644
# Epoch 9/30
# 274/274 [==============================] - 0s 861us/step - loss: 1.5551
# Epoch 10/30
# 274/274 [==============================] - 0s 746us/step - loss: 1.5450
# Epoch 11/30
# 274/274 [==============================] - 0s 673us/step - loss: 1.5380
# Epoch 12/30
# 274/274 [==============================] - 0s 633us/step - loss: 1.5299
# Epoch 13/30
# 274/274 [==============================] - 0s 645us/step - loss: 1.5229
# Epoch 14/30
# 274/274 [==============================] - 0s 684us/step - loss: 1.5167
# Epoch 15/30
# 274/274 [==============================] - 0s 551us/step - loss: 1.5102
# Epoch 16/30
# 274/274 [==============================] - 0s 546us/step - loss: 1.5040
# Epoch 17/30
# 274/274 [==============================] - 0s 786us/step - loss: 1.4979
# Epoch 18/30
# 274/274 [==============================] - 0s 656us/step - loss: 1.4925
# Epoch 19/30
# 274/274 [==============================] - 0s 595us/step - loss: 1.4882
# Epoch 20/30
# 274/274 [==============================] - 0s 658us/step - loss: 1.4824
# Epoch 21/30
# 274/274 [==============================] - 0s 679us/step - loss: 1.4768
# Epoch 22/30
# 274/274 [==============================] - 0s 647us/step - loss: 1.4742
# Epoch 23/30
# 274/274 [==============================] - 0s 675us/step - loss: 1.4699
# Epoch 24/30
# 274/274 [==============================] - 0s 663us/step - loss: 1.4665
# Epoch 25/30
# 274/274 [==============================] - 0s 587us/step - loss: 1.4623
# Epoch 26/30
# 274/274 [==============================] - 0s 611us/step - loss: 1.4595
# Epoch 27/30
# 274/274 [==============================] - 0s 708us/step - loss: 1.4554
# Epoch 28/30
# 274/274 [==============================] - 0s 671us/step - loss: 1.4526
# Epoch 29/30
# 274/274 [==============================] - 0s 634us/step - loss: 1.4507
# Epoch 30/30
# 274/274 [==============================] - 0s 676us/step - loss: 1.4463
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 2, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': -1}
# iter 3
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 4, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': 1}
# iter 4
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 3, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': -1}
# iter 5
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 18, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': 1}
# iter 6
# Time taken: 11.47 seconds.
# [0.300443458262103, 0.45454545454545453, 0.1288981288981289]
# log4j
# =====
# iter 1
# Epoch 1/30
# 40/40 [==============================] - 0s 594us/step - loss: 1.5271
# Epoch 2/30
# 40/40 [==============================] - 0s 701us/step - loss: 1.5088
# Epoch 3/30
# 40/40 [==============================] - 0s 613us/step - loss: 1.4975
# Epoch 4/30
# 40/40 [==============================] - 0s 633us/step - loss: 1.4871
# Epoch 5/30
# 40/40 [==============================] - 0s 681us/step - loss: 1.4767
# Epoch 6/30
# 40/40 [==============================] - 0s 658us/step - loss: 1.4664
# Epoch 7/30
# 40/40 [==============================] - 0s 700us/step - loss: 1.4560
# Epoch 8/30
# 40/40 [==============================] - 0s 731us/step - loss: 1.4454
# Epoch 9/30
# 40/40 [==============================] - 0s 713us/step - loss: 1.4355
# Epoch 10/30
# 40/40 [==============================] - 0s 731us/step - loss: 1.4260
# Epoch 11/30
# 40/40 [==============================] - 0s 660us/step - loss: 1.4167
# Epoch 12/30
# 40/40 [==============================] - 0s 684us/step - loss: 1.4067
# Epoch 13/30
# 40/40 [==============================] - 0s 710us/step - loss: 1.3979
# Epoch 14/30
# 40/40 [==============================] - 0s 668us/step - loss: 1.3882
# Epoch 15/30
# 40/40 [==============================] - 0s 618us/step - loss: 1.3802
# Epoch 16/30
# 40/40 [==============================] - 0s 709us/step - loss: 1.3703
# Epoch 17/30
# 40/40 [==============================] - 0s 712us/step - loss: 1.3619
# Epoch 18/30
# 40/40 [==============================] - 0s 953us/step - loss: 1.3543
# Epoch 19/30
# 40/40 [==============================] - 0s 738us/step - loss: 1.3459
# Epoch 20/30
# 40/40 [==============================] - 0s 648us/step - loss: 1.3371
# Epoch 21/30
# 40/40 [==============================] - 0s 714us/step - loss: 1.3292
# Epoch 22/30
# 40/40 [==============================] - 0s 745us/step - loss: 1.3218
# Epoch 23/30
# 40/40 [==============================] - 0s 701us/step - loss: 1.3142
# Epoch 24/30
# ...
# 40/40 [==============================] - 0s 597us/step - loss: 1.3566
# Epoch 22/30
# 40/40 [==============================] - 0s 625us/step - loss: 1.3413
# Epoch 23/30
# 40/40 [==============================] - 0s 661us/step - loss: 1.3268
# Epoch 24/30
# 40/40 [==============================] - 0s 599us/step - loss: 1.3122
# Epoch 25/30
# 40/40 [==============================] - 0s 659us/step - loss: 1.2973
# Epoch 26/30
# 40/40 [==============================] - 0s 582us/step - loss: 1.2833
# Epoch 27/30
# 40/40 [==============================] - 0s 651us/step - loss: 1.2698
# Epoch 28/30
# 40/40 [==============================] - 0s 632us/step - loss: 1.2568
# Epoch 29/30
# 40/40 [==============================] - 0s 754us/step - loss: 1.2451
# Epoch 30/30
# 40/40 [==============================] - 0s 723us/step - loss: 1.2337
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 2, 'trend': 1}
# iter 3
# Epoch 1/30
# 40/40 [==============================] - 0s 663us/step - loss: 1.5331
# Epoch 2/30
# 40/40 [==============================] - 0s 827us/step - loss: 1.5305
# Epoch 3/30
# 40/40 [==============================] - 0s 902us/step - loss: 1.5279
# Epoch 4/30
# 40/40 [==============================] - 0s 742us/step - loss: 1.5252
# Epoch 5/30
# 40/40 [==============================] - 0s 772us/step - loss: 1.5212
# Epoch 6/30
# 40/40 [==============================] - 0s 758us/step - loss: 1.5164
# Epoch 7/30
# 40/40 [==============================] - 0s 776us/step - loss: 1.5102
# Epoch 8/30
# 40/40 [==============================] - 0s 735us/step - loss: 1.5030
# Epoch 9/30
# 40/40 [==============================] - 0s 778us/step - loss: 1.4951
# Epoch 10/30
# 40/40 [==============================] - 0s 919us/step - loss: 1.4835
# Epoch 11/30
# 40/40 [==============================] - 0s 789us/step - loss: 1.4717
# Epoch 12/30
# 40/40 [==============================] - 0s 685us/step - loss: 1.4589
# Epoch 13/30
# 40/40 [==============================] - 0s 666us/step - loss: 1.4455
# Epoch 14/30
# 40/40 [==============================] - 0s 753us/step - loss: 1.4314
# Epoch 15/30
# 40/40 [==============================] - 0s 636us/step - loss: 1.4179
# Epoch 16/30
# 40/40 [==============================] - 0s 631us/step - loss: 1.4033
# Epoch 17/30
# 40/40 [==============================] - 0s 657us/step - loss: 1.3885
# Epoch 18/30
# 40/40 [==============================] - 0s 647us/step - loss: 1.3740
# Epoch 19/30
# 40/40 [==============================] - 0s 665us/step - loss: 1.3590
# Epoch 20/30
# 40/40 [==============================] - 0s 637us/step - loss: 1.3443
# Epoch 21/30
# 40/40 [==============================] - 0s 729us/step - loss: 1.3308
# Epoch 22/30
# 40/40 [==============================] - 0s 668us/step - loss: 1.3185
# Epoch 23/30
# 40/40 [==============================] - 0s 632us/step - loss: 1.3055
# Epoch 24/30
# 40/40 [==============================] - 0s 660us/step - loss: 1.2937
# Epoch 25/30
# 40/40 [==============================] - 0s 667us/step - loss: 1.2818
# Epoch 26/30
# 40/40 [==============================] - 0s 700us/step - loss: 1.2697
# Epoch 27/30
# 40/40 [==============================] - 0s 630us/step - loss: 1.2594
# Epoch 28/30
# 40/40 [==============================] - 0s 787us/step - loss: 1.2487
# Epoch 29/30
# 40/40 [==============================] - 0s 694us/step - loss: 1.2395
# Epoch 30/30
# 40/40 [==============================] - 0s 641us/step - loss: 1.2306
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 3, 'trend': 1}
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': -1}
# iter 4
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 4, 'trend': -1}
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': 1}
# iter 5
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 3, 'trend': 1}
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': -1}
# iter 6
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 18, 'trend': -1}
# {'n_layers': 3, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': 1}
# iter 7
# Time taken: 4.38 seconds.
# [0.15273035550235103, 0.6613756613756614, 0.5]
# xalan
# =====
# iter 1
# Epoch 1/30
# 398/398 [==============================] - 0s 546us/step - loss: 1.2500
# Epoch 2/30
# 398/398 [==============================] - 0s 1ms/step - loss: 1.2083
# Epoch 3/30
# 398/398 [==============================] - 0s 529us/step - loss: 1.1877
# Epoch 4/30
# 398/398 [==============================] - 0s 480us/step - loss: 1.1649
# Epoch 5/30
# 398/398 [==============================] - 0s 532us/step - loss: 1.1431
# Epoch 6/30
# 398/398 [==============================] - 0s 491us/step - loss: 1.1275
# Epoch 7/30
# 398/398 [==============================] - 0s 540us/step - loss: 1.1147
# Epoch 8/30
# 398/398 [==============================] - 0s 478us/step - loss: 1.1038
# Epoch 9/30
# 398/398 [==============================] - 0s 473us/step - loss: 1.0949
# Epoch 10/30
# 398/398 [==============================] - 0s 464us/step - loss: 1.0869
# Epoch 11/30
# 398/398 [==============================] - 0s 469us/step - loss: 1.0803
# Epoch 12/30
# 398/398 [==============================] - 0s 497us/step - loss: 1.0745
# Epoch 13/30
# 398/398 [==============================] - 0s 460us/step - loss: 1.0692
# Epoch 14/30
# 398/398 [==============================] - 0s 464us/step - loss: 1.0646
# Epoch 15/30
# 398/398 [==============================] - 0s 474us/step - loss: 1.0602
# Epoch 16/30
# 398/398 [==============================] - 0s 494us/step - loss: 1.0565
# Epoch 17/30
# 398/398 [==============================] - 0s 518us/step - loss: 1.0525
# Epoch 18/30
# 398/398 [==============================] - 0s 903us/step - loss: 1.0495
# Epoch 19/30
# 398/398 [==============================] - 0s 512us/step - loss: 1.0465
# Epoch 20/30
# 398/398 [==============================] - 0s 526us/step - loss: 1.0430
# Epoch 21/30
# 398/398 [==============================] - 0s 503us/step - loss: 1.0401
# Epoch 22/30
# 398/398 [==============================] - 0s 623us/step - loss: 1.0375
# Epoch 23/30
# 398/398 [==============================] - 0s 508us/step - loss: 1.0347
# Epoch 24/30
# 398/398 [==============================] - 0s 494us/step - loss: 1.0327
# Epoch 25/30
# 398/398 [==============================] - 0s 612us/step - loss: 1.0303
# Epoch 26/30
# 398/398 [==============================] - 0s 668us/step - loss: 1.0286
# Epoch 27/30
# 398/398 [==============================] - 0s 625us/step - loss: 1.0263
# Epoch 28/30
# 398/398 [==============================] - 0s 604us/step - loss: 1.0244
# Epoch 29/30
# 398/398 [==============================] - 0s 714us/step - loss: 1.0229
# Epoch 30/30
# 398/398 [==============================] - 0s 623us/step - loss: 1.0212
# {'n_layers': 1, 'n_units': 3, 'preprocessor': 'normalize'} {}
# iter 2
# Epoch 1/30
# 398/398 [==============================] - 0s 658us/step - loss: 1.2219
# Epoch 2/30
# 398/398 [==============================] - 0s 628us/step - loss: 1.1783
# Epoch 3/30
# 398/398 [==============================] - 0s 624us/step - loss: 1.1623
# Epoch 4/30
# 398/398 [==============================] - 0s 561us/step - loss: 1.1537
# Epoch 5/30
# 398/398 [==============================] - 0s 619us/step - loss: 1.1480
# Epoch 6/30
# 398/398 [==============================] - 0s 572us/step - loss: 1.1424
# Epoch 7/30
# 398/398 [==============================] - 0s 606us/step - loss: 1.1385
# Epoch 8/30
# 398/398 [==============================] - 0s 581us/step - loss: 1.1341
# Epoch 9/30
# 398/398 [==============================] - 0s 686us/step - loss: 1.1300
# Epoch 10/30
# 398/398 [==============================] - 0s 632us/step - loss: 1.1236
# Epoch 11/30
# 398/398 [==============================] - 0s 609us/step - loss: 1.1147
# Epoch 12/30
# 398/398 [==============================] - 0s 645us/step - loss: 1.1022
# Epoch 13/30
# 398/398 [==============================] - 0s 652us/step - loss: 1.0851
# Epoch 14/30
# 398/398 [==============================] - 0s 675us/step - loss: 1.0679
# Epoch 15/30
# 398/398 [==============================] - 0s 657us/step - loss: 1.0520
# Epoch 16/30
# 398/398 [==============================] - 0s 820us/step - loss: 1.0375
# Epoch 17/30
# 398/398 [==============================] - 0s 664us/step - loss: 1.0256
# Epoch 18/30
# 398/398 [==============================] - 0s 601us/step - loss: 1.0151
# Epoch 19/30
# 398/398 [==============================] - 0s 543us/step - loss: 1.0061
# Epoch 20/30
# 398/398 [==============================] - 0s 628us/step - loss: 0.9982
# Epoch 21/30
# 398/398 [==============================] - 0s 658us/step - loss: 0.9917
# Epoch 22/30
# 398/398 [==============================] - 0s 624us/step - loss: 0.9863
# Epoch 23/30
# 398/398 [==============================] - 0s 643us/step - loss: 0.9803
# Epoch 24/30
# 398/398 [==============================] - 0s 622us/step - loss: 0.9766
# Epoch 25/30
# 398/398 [==============================] - 0s 698us/step - loss: 0.9729
# Epoch 26/30
# 398/398 [==============================] - 0s 561us/step - loss: 0.9687
# Epoch 27/30
# 398/398 [==============================] - 0s 555us/step - loss: 0.9668
# Epoch 28/30
# 398/398 [==============================] - 0s 610us/step - loss: 0.9650
# Epoch 29/30
# 398/398 [==============================] - 0s 628us/step - loss: 0.9619
# Epoch 30/30
# 398/398 [==============================] - 0s 669us/step - loss: 0.9601
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 2, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': -1}
# iter 3
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 4, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': 1}
# iter 4
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 3, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': -1}
# iter 5
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 18, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': 1}
# iter 6
# Time taken: 15.48 seconds.
# [0.06929331486015167, 0.09799554565701558, 0.0]
# xerces
# ======
# iter 1
# Epoch 1/30
# 184/184 [==============================] - 0s 728us/step - loss: 2.5801
# Epoch 2/30
# 184/184 [==============================] - 0s 630us/step - loss: 2.5608
# Epoch 3/30
# 184/184 [==============================] - 0s 695us/step - loss: 2.5115
# Epoch 4/30
# 184/184 [==============================] - 0s 692us/step - loss: 2.4717
# Epoch 5/30
# 184/184 [==============================] - 0s 706us/step - loss: 2.4436
# Epoch 6/30
# 184/184 [==============================] - 0s 670us/step - loss: 2.4166
# Epoch 7/30
# 184/184 [==============================] - 0s 657us/step - loss: 2.3941
# Epoch 8/30
# 184/184 [==============================] - 0s 632us/step - loss: 2.3774
# Epoch 9/30
# 184/184 [==============================] - 0s 571us/step - loss: 2.3649
# Epoch 10/30
# 184/184 [==============================] - 0s 542us/step - loss: 2.3541
# Epoch 11/30
# 184/184 [==============================] - 0s 538us/step - loss: 2.3453
# Epoch 12/30
# 184/184 [==============================] - 0s 534us/step - loss: 2.3378
# Epoch 13/30
# 184/184 [==============================] - 0s 564us/step - loss: 2.3302
# Epoch 14/30
# 184/184 [==============================] - 0s 540us/step - loss: 2.3224
# Epoch 15/30
# 184/184 [==============================] - 0s 518us/step - loss: 2.3146
# Epoch 16/30
# 184/184 [==============================] - 0s 521us/step - loss: 2.3079
# Epoch 17/30
# 184/184 [==============================] - 0s 514us/step - loss: 2.3010
# Epoch 18/30
# 184/184 [==============================] - 0s 521us/step - loss: 2.2943
# Epoch 19/30
# 184/184 [==============================] - 0s 542us/step - loss: 2.2877
# Epoch 20/30
# 184/184 [==============================] - 0s 519us/step - loss: 2.2804
# Epoch 21/30
# 184/184 [==============================] - 0s 501us/step - loss: 2.2724
# Epoch 22/30
# 184/184 [==============================] - 0s 510us/step - loss: 2.2643
# Epoch 23/30
# 184/184 [==============================] - 0s 585us/step - loss: 2.2566
# Epoch 24/30
# 184/184 [==============================] - 0s 568us/step - loss: 2.2484
# Epoch 25/30
# 184/184 [==============================] - 0s 594us/step - loss: 2.2381
# Epoch 26/30
# 184/184 [==============================] - 0s 605us/step - loss: 2.2236
# Epoch 27/30
# 184/184 [==============================] - 0s 645us/step - loss: 2.2063
# Epoch 28/30
# 184/184 [==============================] - 0s 719us/step - loss: 2.1894
# Epoch 29/30
# 184/184 [==============================] - 0s 640us/step - loss: 2.1712
# Epoch 30/30
# 184/184 [==============================] - 0s 589us/step - loss: 2.1514
# {'n_layers': 1, 'n_units': 3, 'preprocessor': 'normalize'} {}
# iter 2
# Epoch 1/30
# 184/184 [==============================] - 0s 1ms/step - loss: 2.5604
# Epoch 2/30
# 184/184 [==============================] - 0s 883us/step - loss: 2.5406
# Epoch 3/30
# 184/184 [==============================] - 0s 687us/step - loss: 2.4973
# Epoch 4/30
# 184/184 [==============================] - 0s 590us/step - loss: 2.4430
# Epoch 5/30
# 184/184 [==============================] - 0s 556us/step - loss: 2.4001
# Epoch 6/30
# 184/184 [==============================] - 0s 557us/step - loss: 2.3611
# Epoch 7/30
# 184/184 [==============================] - 0s 568us/step - loss: 2.3314
# Epoch 8/30
# 184/184 [==============================] - 0s 624us/step - loss: 2.3040
# Epoch 9/30
# 184/184 [==============================] - 0s 672us/step - loss: 2.2749
# Epoch 10/30
# 184/184 [==============================] - 0s 625us/step - loss: 2.2434
# Epoch 11/30
# 184/184 [==============================] - 0s 911us/step - loss: 2.2103
# Epoch 12/30
# 184/184 [==============================] - 0s 814us/step - loss: 2.1788
# Epoch 13/30
# 184/184 [==============================] - 0s 703us/step - loss: 2.1493
# Epoch 14/30
# 184/184 [==============================] - 0s 767us/step - loss: 2.1223
# Epoch 15/30
# 184/184 [==============================] - 0s 774us/step - loss: 2.1007
# Epoch 16/30
# 184/184 [==============================] - 0s 729us/step - loss: 2.0770
# Epoch 17/30
# 184/184 [==============================] - 0s 618us/step - loss: 2.0538
# Epoch 18/30
# 184/184 [==============================] - 0s 584us/step - loss: 2.0338
# Epoch 19/30
# 184/184 [==============================] - 0s 581us/step - loss: 2.0164
# Epoch 20/30
# 184/184 [==============================] - 0s 578us/step - loss: 1.9990
# Epoch 21/30
# 184/184 [==============================] - 0s 565us/step - loss: 1.9820
# Epoch 22/30
# 184/184 [==============================] - 0s 590us/step - loss: 1.9663
# Epoch 23/30
# 184/184 [==============================] - 0s 592us/step - loss: 1.9481
# Epoch 24/30
# 184/184 [==============================] - 0s 587us/step - loss: 1.9317
# Epoch 25/30
# 184/184 [==============================] - 0s 684us/step - loss: 1.9145
# Epoch 26/30
# 184/184 [==============================] - 0s 603us/step - loss: 1.8958
# Epoch 27/30
# 184/184 [==============================] - 0s 600us/step - loss: 1.8763
# Epoch 28/30
# 184/184 [==============================] - 0s 609us/step - loss: 1.8594
# Epoch 29/30
# 184/184 [==============================] - 0s 576us/step - loss: 1.8404
# Epoch 30/30
# 184/184 [==============================] - 0s 603us/step - loss: 1.8189
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 2, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': -1}
# iter 3
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 4, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_layers': 5, 'trend': 1}
# iter 4
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 3, 'trend': 1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': -1}
# iter 5
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 18, 'trend': -1}
# {'n_layers': 2, 'n_units': 3, 'preprocessor': 'normalize'} {'n_units': 20, 'trend': 1}
# iter 6
# Time taken: 8.15 seconds.
# [0.060454078274451484, 0.10297482837528604, 0.12582781456953643]
