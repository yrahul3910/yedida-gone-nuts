# %%
import pandas as pd
import numpy as np
from keras.utils.np_utils import to_categorical
from keras.layers import Dense, BatchNormalization
from keras.models import Sequential
from sklearn.metrics import f1_score, recall_score, precision_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
# Out:
# Using TensorFlow backend.

# %%
path = "../Dodge/data/issue_close_time/"

# %%
dirs = ["1 day", "7 days", "30 days", "90 days", "180 days", "365 days"]

# %%
datasets = ["camel", "cocoon", "hive", "hadoop", "cloudstack", "deeplearning", "node", "ofbiz", "qpid"]

# %%
# from https://stackoverflow.com/questions/30564015/how-to-generate-random-points-in-a-circular-distribution
def fuzz_data(X, y, radii=(0., .3, .03), classes=[0, 1, 2, 3, 4, 5]):
    counts = []
    for i in classes:
        counts.append(len(np.where(y == i)[0]))
    
    lcm = np.lcm.reduce(counts)
    print("counts =", counts)
    print("lcm =", lcm)
    
    fuzzed_x = []
    fuzzed_y = []
    
    for _, c in enumerate(classes):
        idx = np.where(y == c)[0]
        frac = counts[_] / sum(counts)
        for row in X[idx]:
            for i, r in enumerate(np.arange(*radii)):
                for j in range(int((1./frac) / pow(2., i))):
                    fuzzed_x.append([val - r for val in row])
                    fuzzed_x.append([val + r for val in row])
                    fuzzed_y.append(c)
                    fuzzed_y.append(c)
    
    print(X.shape, np.array(fuzzed_x).shape, y.shape, np.array(fuzzed_y).shape)
    return np.concatenate((X, np.array(fuzzed_x)), axis=0), np.concatenate((y, np.array(fuzzed_y)))

# %%
_ = pd.read_csv(f"{path}1 day/camel.csv")

# %%
for data in datasets:
    write_train = pd.DataFrame(data=[], columns=_.columns)
    write_test = pd.DataFrame(data=[], columns=_.columns)
    for time in dirs:
        df = pd.read_csv(f"{path}{time}/{data}.csv")
        train_df, test_df = train_test_split(df, test_size=.3)
        
        for row in train_df.iterrows():
            if row[1]["timeOpen"]:
                row[1]["timeOpen"] = time
                write_train = write_train.append(row[1])
        
        for row in test_df.iterrows():
            if row[1]["timeOpen"]:
                row[1]["timeOpen"] = time
                write_test = write_test.append(row[1])
                
    write_train.to_csv("./data/" + data + "_train.csv")
    write_test.to_csv("./data/" + data + "_test.csv")

# %%
df = pd.read_csv("camel.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  issueCleanedBodyLen  meanCommentSizeT  nActorsT  nCommentsT  \
# 0           2                   11                14         3           1
# 1           3                   11                 0         2           0
# 2           4                    8                30         3           2
# 3           5                   33                19         2           2
# 4           6                    6                 8         2           2
#
#    nCommitsByActorsT  nCommitsByCreator  nCommitsByUniqueActorsT  \
# 0               8113                  0                      255
# 1               2307                  0                      113
# 2               1338                  0                       80
# 3               3256                  0                      150
# 4                814                  1                       62
#
#    nCommitsInProject  nCommitsProjectT  nIssuesByCreator  \
# 0                452              8223                 1
# 1                789              2443                 6
# 2               1058              1506                 1
# 3                972              3429                 1
# 4               1192              1023                 3
#
#    nIssuesByCreatorClosed  nIssuesCreatedInProject  \
# 0                       0                      258
# 1                       1                      384
# 2                       0                      434
# 3                       0                      377
# 4                       1                      493
#
#    nIssuesCreatedInProjectClosed  nIssuesCreatedProjectClosedT  \
# 0                             34                          1006
# 1                            107                           321
# 2                            171                           164
# 3                             81                           450
# 4                            179                            89
#
#    nIssuesCreatedProjectT  nLabelsT  nSubscribedByT timeOpen
# 0                    3694         0               0    1 day
# 1                     953         0               0    1 day
# 2                     572         0               2    1 day
# 3                    1406         0               0    1 day
# 4                     359         0               0    1 day

# %%
df = df[df.columns[1:]]

# %%
df.head()
# Out:
#    issueCleanedBodyLen  meanCommentSizeT  nActorsT  nCommentsT  \
# 0                   11                14         3           1
# 1                   11                 0         2           0
# 2                    8                30         3           2
# 3                   33                19         2           2
# 4                    6                 8         2           2
#
#    nCommitsByActorsT  nCommitsByCreator  nCommitsByUniqueActorsT  \
# 0               8113                  0                      255
# 1               2307                  0                      113
# 2               1338                  0                       80
# 3               3256                  0                      150
# 4                814                  1                       62
#
#    nCommitsInProject  nCommitsProjectT  nIssuesByCreator  \
# 0                452              8223                 1
# 1                789              2443                 6
# 2               1058              1506                 1
# 3                972              3429                 1
# 4               1192              1023                 3
#
#    nIssuesByCreatorClosed  nIssuesCreatedInProject  \
# 0                       0                      258
# 1                       1                      384
# 2                       0                      434
# 3                       0                      377
# 4                       1                      493
#
#    nIssuesCreatedInProjectClosed  nIssuesCreatedProjectClosedT  \
# 0                             34                          1006
# 1                            107                           321
# 2                            171                           164
# 3                             81                           450
# 4                            179                            89
#
#    nIssuesCreatedProjectT  nLabelsT  nSubscribedByT timeOpen
# 0                    3694         0               0    1 day
# 1                     953         0               0    1 day
# 2                     572         0               2    1 day
# 3                    1406         0               0    1 day
# 4                     359         0               0    1 day

# %%
x = df.drop("timeOpen", axis=1)
y = df["timeOpen"]

# %%
x.shape
# Out:
# (4310, 17)

# %%
x = np.array(x)

# %%
y = np.array([dirs.index(t) for t in y])

# %%
y.shape
# Out:
# (4310,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
x_train, y_train = fuzz_data(x_train, y_train)
# Out:
# counts = [544, 347, 139, 242, 518, 1658]
# lcm = 681683590361312
# (3448, 17) (67180, 17) (3448,) (67180,)

# %%
y_train = to_categorical(y_train, num_classes=6)
y_test = to_categorical(y_test, num_classes=6)

# %%
model = Sequential([
    Dense(17, activation='relu'),
    BatchNormalization(),
    Dense(17, activation='relu'),
    BatchNormalization(),
    Dense(17, activation='relu'),
    BatchNormalization(),
    Dense(17, activation='relu'),
    BatchNormalization(),
    Dense(6, activation='softmax')
])

# %%
model.compile(optimizer='adadelta', loss='categorical_crossentropy')

# %%
model.fit(x_train, y_train, batch_size=128, epochs=200)
# Out:
# Epoch 1/200
# 70628/70628 [==============================] - 2s 25us/step - loss: 1.3461
# Epoch 2/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 1.2141
# Epoch 3/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 1.1658
# Epoch 4/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 1.1396
# Epoch 5/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 1.1161
# Epoch 6/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 1.1048
# Epoch 7/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 1.0846
# Epoch 8/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 1.0652
# Epoch 9/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 1.0514
# Epoch 10/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 1.0385
# Epoch 11/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 1.0274
# Epoch 12/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 1.0146
# Epoch 13/200
# 70628/70628 [==============================] - 1s 16us/step - loss: 1.0096
# Epoch 14/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.9995
# Epoch 15/200
# 70628/70628 [==============================] - 1s 16us/step - loss: 0.9918
# Epoch 16/200
# 70628/70628 [==============================] - 1s 16us/step - loss: 0.9829
# Epoch 17/200
# 70628/70628 [==============================] - 1s 16us/step - loss: 0.9773
# Epoch 18/200
# 70628/70628 [==============================] - 1s 17us/step - loss: 0.9674
# Epoch 19/200
# 70628/70628 [==============================] - 1s 17us/step - loss: 0.9641
# Epoch 20/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.9604
# Epoch 21/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.9557
# Epoch 22/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.9471
# Epoch 23/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.9436
# Epoch 24/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.9407
# Epoch 25/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.9311
# Epoch 26/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.9287
# Epoch 27/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.9245
# Epoch 28/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.9237
# Epoch 29/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.9199
# Epoch 30/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.9128
# Epoch 31/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.9105
# Epoch 32/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.9073
# Epoch 33/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.9025
# Epoch 34/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8991
# Epoch 35/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.9005
# Epoch 36/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8929
# Epoch 37/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8961
# Epoch 38/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8900
# Epoch 39/200
# 70628/70628 [==============================] - 1s 16us/step - loss: 0.8839
# Epoch 40/200
# 70628/70628 [==============================] - 1s 16us/step - loss: 0.8860
# Epoch 41/200
# 70628/70628 [==============================] - 1s 16us/step - loss: 0.8862
# Epoch 42/200
# 70628/70628 [==============================] - 1s 16us/step - loss: 0.8790
# Epoch 43/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8758
# Epoch 44/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8749
# Epoch 45/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8774
# Epoch 46/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8743
# Epoch 47/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8693
# Epoch 48/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8655
# Epoch 49/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8621
# Epoch 50/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8666
# Epoch 51/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8662
# Epoch 52/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8651
# Epoch 53/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8603
# Epoch 54/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8572
# Epoch 55/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8570
# Epoch 56/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8545
# Epoch 57/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8519
# Epoch 58/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8498
# Epoch 59/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8489
# Epoch 60/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8461
# Epoch 61/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8454
# Epoch 62/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8431
# Epoch 63/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.8433
# Epoch 64/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8360
# Epoch 65/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8508
# Epoch 66/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.8414
# Epoch 67/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8379
# Epoch 68/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8385
# Epoch 69/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8356
# Epoch 70/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8338
# Epoch 71/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8382
# Epoch 72/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8307
# Epoch 73/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8333
# Epoch 74/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8284
# Epoch 75/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8291
# Epoch 76/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8269
# Epoch 77/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8306
# Epoch 78/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8246
# Epoch 79/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8276
# Epoch 80/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8226
# Epoch 81/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8180
# Epoch 82/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8223
# Epoch 83/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8180
# Epoch 84/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8165
# Epoch 85/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8198
# Epoch 86/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8171
# Epoch 87/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8145
# Epoch 88/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8155
# Epoch 89/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8131
# Epoch 90/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.8210
# Epoch 91/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8080
# Epoch 92/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8147
# Epoch 93/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8113
# Epoch 94/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8085
# Epoch 95/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8083
# Epoch 96/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.8055
# Epoch 97/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.8023
# Epoch 98/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.8021
# Epoch 99/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8020
# Epoch 100/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.8029
# Epoch 101/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7976
# Epoch 102/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7987
# Epoch 103/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7942
# Epoch 104/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7952
# Epoch 105/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7953
# Epoch 106/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7996
# Epoch 107/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7913
# Epoch 108/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7928
# Epoch 109/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7911
# Epoch 110/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7929
# Epoch 111/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7837
# Epoch 112/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7914
# Epoch 113/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7899
# Epoch 114/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7915
# Epoch 115/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7866
# Epoch 116/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7889
# Epoch 117/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7901
# Epoch 118/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7881
# Epoch 119/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7814
# Epoch 120/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7827
# Epoch 121/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7810
# Epoch 122/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7838
# Epoch 123/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7828
# Epoch 124/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7782
# Epoch 125/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7827
# Epoch 126/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7813
# Epoch 127/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7763
# Epoch 128/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7772
# Epoch 129/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7749
# Epoch 130/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7711
# Epoch 131/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7753
# Epoch 132/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7750
# Epoch 133/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7734
# Epoch 134/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7761
# Epoch 135/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7691
# Epoch 136/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7707
# Epoch 137/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7692
# Epoch 138/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7698
# Epoch 139/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7701
# Epoch 140/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7661
# Epoch 141/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7695
# Epoch 142/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7653
# Epoch 143/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7683
# Epoch 144/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7668
# Epoch 145/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7610
# Epoch 146/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7668
# Epoch 147/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7637
# Epoch 148/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7617
# Epoch 149/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7633
# Epoch 150/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7615
# Epoch 151/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7591
# Epoch 152/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7607
# Epoch 153/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7593
# Epoch 154/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7578
# Epoch 155/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7559
# Epoch 156/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7579
# Epoch 157/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7532
# Epoch 158/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7558
# Epoch 159/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7563
# Epoch 160/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7572
# Epoch 161/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7612
# Epoch 162/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7555
# Epoch 163/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7523
# Epoch 164/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7497
# Epoch 165/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7524
# Epoch 166/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7485
# Epoch 167/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7544
# Epoch 168/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7471
# Epoch 169/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7485
# Epoch 170/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7505
# Epoch 171/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7496
# Epoch 172/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7506
# Epoch 173/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7487
# Epoch 174/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7442
# Epoch 175/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7433
# Epoch 176/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7430
# Epoch 177/200
# 70628/70628 [==============================] - 2s 22us/step - loss: 0.7428
# Epoch 178/200
# 70628/70628 [==============================] - 1s 17us/step - loss: 0.7469
# Epoch 179/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7457
# Epoch 180/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7453
# Epoch 181/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7369
# Epoch 182/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7456
# Epoch 183/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7408
# Epoch 184/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7383
# Epoch 185/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7465
# Epoch 186/200
# 70628/70628 [==============================] - 1s 13us/step - loss: 0.7450
# Epoch 187/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7448
# Epoch 188/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7390
# Epoch 189/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7389
# Epoch 190/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7383
# Epoch 191/200
# 70628/70628 [==============================] - 1s 16us/step - loss: 0.7392
# Epoch 192/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7358
# Epoch 193/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7401
# Epoch 194/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7346
# Epoch 195/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7397
# Epoch 196/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7342
# Epoch 197/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7412
# Epoch 198/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7373
# Epoch 199/200
# 70628/70628 [==============================] - 1s 14us/step - loss: 0.7316
# Epoch 200/200
# 70628/70628 [==============================] - 1s 15us/step - loss: 0.7328

# %%
preds = model.predict_classes(x_test)

# %%
print(classification_report(np.argmax(y_test, axis=1), preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63       154
#            1       0.27      0.32      0.29        90
#            2       0.07      0.21      0.11        28
#            3       0.27      0.52      0.35        58
#            4       0.38      0.60      0.47       139
#            5       0.93      0.44      0.60       393
#
#     accuracy                           0.49       862
#    macro avg       0.42      0.45      0.41       862
# weighted avg       0.65      0.49      0.52       862

# %%
f1_score(np.argmax(y_test, axis=1), preds, average=None)
# Out:
# array([0.62783172, 0.29292929, 0.10909091, 0.35087719, 0.46629213,
#        0.6       ])

# %%
def distill(x, y, model):
    synthetic_data = np.random.uniform(size=(int(1e5), x.shape[0])) * (np.amax(x, axis=0) - np.amin(x, axis=0)) + np.amin(x, axis=0)
    preds = model.predict_classes(synthetic_data)
    
    student = DecisionTreeClassifier()
    student.fit(synthetic_data, preds)
    return student

# %%
student = distill(x_train, y_train, model)

# %%
stu_preds = student.predict(x_test)
print(classification_report(np.argmax(y_test, axis=1), stu_preds))
