# %%
from raise_utils.transforms import Transform
from raise_utils.data import Data
from sklearn.datasets import make_moons
from matplotlib import pyplot as plt

# %%
X, y = make_moons(n_samples=200)
data = Data(X, None, y, None)

# %%
plt.figure(dpi=150)
plt.scatter(X.T[0], X.T[1], c=y);

# %%
transform = Transform('wfo')
transform.apply(data)
# Out:
# wfo

# %%
plt.figure(dpi=150)
plt.scatter(data.x_train.T[0], data.x_train.T[1], c=data.y_train, alpha=0.3)

# %%
transform.apply(data)
transform = Transform('smote')
transform.apply(data)
# Out:
# wfo
# smote

# %%
plt.figure(dpi=150)
plt.scatter(data.x_train.T[0], data.x_train.T[1], c=data.y_train, alpha=0.2)
